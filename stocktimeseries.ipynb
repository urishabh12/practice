# 2017-09-30  133.006950
# 2018-09-30  179.698450
# 2019-09-30  192.747391

# %%
##difference

# %%
aapl['diff'] = aapl.Open - aapl.Close
print(aapl['diff'])
# Out:
# Date
# 2011-09-30    0.828571
# 2011-10-03    0.824284
# 2011-10-04    0.295712
# 2011-10-05   -1.484283
# 2011-10-06   -0.577141
# 2011-10-07    0.854286
# 2011-10-10   -1.388569
# 2011-10-11   -1.102856
# 2011-10-12    0.735714
# 2011-10-13   -0.492855
# 2011-10-14   -0.738571
# 2011-10-17    0.250000
# 2011-10-18   -0.068573
# 2011-10-19    0.389999
# 2011-10-20    0.669998
# 2011-10-21    0.747143
# 2011-10-24   -1.370003
# 2011-10-25    1.037140
# 2011-10-26    0.165714
# 2011-10-27    0.410000
# 2011-10-28   -0.278568
# 2011-10-31   -0.337143
# 2011-11-01    0.128571
# 2011-11-02    0.382858
# 2011-11-03   -0.571430
# 2011-11-04    0.255714
# 2011-11-07    0.025715
# 2011-11-08   -0.574284
# 2011-11-09    0.241428
# 2011-11-10    1.687141
#                 ...
# 2018-11-15   -3.020004
# 2018-11-16   -3.029999
# 2018-11-19    4.139999
# 2018-11-20    1.389999
# 2018-11-21    2.949997
# 2018-11-23    2.650009
# 2018-11-26   -0.379990
# 2018-11-27   -2.730011
# ...

# %%
import matplotlib.pyplot as plt
aapl['Close'].plot(grid=True)
plt.show()

# %%
##can be ploted montly quarterly and yearwise

# %%
year['Close'].plot(grid=True)
plt.show()

# %%
##histogram

# %%
aapl['Volume'].hist(bins=50,figsize=(12,8))
plt.show()

# %%
##matrix plot

# %%
##stock daily percantage change

# %%
import numpy as np

# %%
daily_close = aapl[['Adj Close']]
daily_pct_change = daily_close.pct_change()
daily_pct_change.fillna(0, inplace=True)
print(daily_pct_change)
daily_log_returns = np.log(daily_close.pct_change()+1)
print(daily_log_returns)
# Out:
#             Adj Close
# Date
# 2011-09-30   0.000000
# 2011-10-03  -0.017623
# 2011-10-04  -0.005606
# 2011-10-05   0.015436
# 2011-10-06  -0.002327
# 2011-10-07  -0.020060
# 2011-10-10   0.051406
# 2011-10-11   0.029526
# 2011-10-12   0.004747
# 2011-10-13   0.015515
# 2011-10-14   0.033225
# 2011-10-17  -0.004763
# 2011-10-18   0.005357
# 2011-10-19  -0.055940
# 2011-10-20  -0.008304
# 2011-10-21  -0.006172
# 2011-10-24   0.032835
# 2011-10-25  -0.019715
# 2011-10-26   0.007115
# 2011-10-27   0.010209
# 2011-10-28   0.000643
# 2011-10-31  -0.000420
# 2011-11-01  -0.020431
# 2011-11-02   0.002270
# 2011-11-03   0.014242
# 2011-11-04  -0.007021
# 2011-11-07  -0.001274
# 2011-11-08   0.016261
# 2011-11-09  -0.026955
# 2011-11-10  -0.025450
# ...               ...
# 2018-11-15   0.024679
# 2018-11-16   0.011076
# 2018-11-19  -0.039632
# 2018-11-20  -0.047778
# 2018-11-21  -0.001130
# 2018-11-23  -0.025399
# 2018-11-26   0.013524
# 2018-11-27  -0.002176
# 2018-11-28   0.038453
# ...

# %%
monthly = aapl.resample('BM').apply(lambda x: x[-1])
monthly.pct_change()
quarter = aapl.resample("4M").mean()
quarter.pct_change()
# Out:
#                 High       Low      Open     Close    Volume  Adj Close  \
# Date
# 2011-09-30       NaN       NaN       NaN       NaN       NaN        NaN
# 2012-01-31  0.038908  0.041363  0.035345  0.050443 -0.224021   0.050442
# 2012-05-31  0.406081  0.398529  0.402731  0.402800  0.503180   0.402800
# 2012-09-30  0.106183  0.113868  0.109022  0.110607 -0.361874   0.126318
# 2013-01-31 -0.100360 -0.108734 -0.101703 -0.106579  0.487564  -0.072121
# 2013-05-31 -0.210709 -0.209196 -0.212544 -0.209671 -0.226449  -0.161154
# 2013-09-30  0.030554  0.035086  0.033392  0.032660 -0.232356   0.098860
# 2014-01-31  0.164276  0.167632  0.164993  0.167103 -0.056190   0.232103
# 2014-05-31  0.036742  0.039029  0.037268  0.038688 -0.172748   0.104817
# 2014-09-30  0.228071  0.225256  0.227633  0.226019 -0.212340   0.269323
# 2015-01-31  0.134026  0.129040  0.132174  0.130855 -0.019619   0.137361
# 2015-05-31  0.158719  0.162504  0.160877  0.161185 -0.050539   0.168043
# ...

# %%
##getting datas of multiple stocks

# %%
def get(tickers, startdate, enddate):
  def data(ticker):
    return (pdr.get_data_yahoo(ticker, start=startdate, end=enddate))
  datas = map (data, tickers)
  return(pdr.concat(datas, keys=tickers, names=['Ticker', 'Date']))

tickers = ['AAPL', 'MSFT', 'IBM', 'GOOG']
all_data = pdr.get_data_yahoo(tickers, datetime.datetime(2006, 10, 1), datetime.datetime(2012, 1, 1))
print(all_data)
# Out:
# Attributes       High                                           Low  \
# Symbols          AAPL        GOOG         IBM       MSFT       AAPL
# Date
# 2006-10-02  10.838572  201.688217   82.470001  27.490000  10.614285
# 2006-10-03  10.707143  201.916733   82.260002  27.480000  10.455714
# 2006-10-04  10.780000  206.541641   83.250000  27.959999  10.451428
# 2006-10-05  10.880000  207.768661   83.209999  28.110001  10.590000
# 2006-10-06  10.720000  209.591812   83.779999  28.000000  10.544286
# 2006-10-09  10.725715  214.579361   84.080002  27.930000  10.504286
# 2006-10-10  10.654285  217.510300   84.629997  27.750000  10.440000
# 2006-10-11  10.568571  213.565964   84.690002  27.670000  10.371428
# 2006-10-12  10.770000  213.451706   84.900002  28.290001  10.514286
# 2006-10-13  10.982857  213.362289   86.209999  28.690001  10.677143
# 2006-10-16  10.840000  213.213257   87.599998  28.600000  10.684286
# 2006-10-17  10.752857  210.505859   87.940002  28.510000  10.577143
# ...

# %%
daily_close_px = all_data['Adj Close']
all_daily_pct=daily_close_px.pct_change()
all_daily_pct.hist(bins=50, sharex=True, figsize=(12,8))
plt.show()

# %%
all_data.head()
# Out:
# Attributes       High                                          Low  \
# Symbols          AAPL        GOOG        IBM       MSFT       AAPL
# Date
# 2006-10-02  10.838572  201.688217  82.470001  27.490000  10.614285
# 2006-10-03  10.707143  201.916733  82.260002  27.480000  10.455714
# 2006-10-04  10.780000  206.541641  83.250000  27.959999  10.451428
# 2006-10-05  10.880000  207.768661  83.209999  28.110001  10.590000
# 2006-10-06  10.720000  209.591812  83.779999  28.000000  10.544286
#
# Attributes                                         Open              \
# Symbols           GOOG        IBM       MSFT       AAPL        GOOG
# Date
# 2006-10-02  199.105011  81.580002  27.150000  10.728572  199.651459
# 2006-10-03  197.808441  81.559998  27.209999  10.635715  199.348434
# 2006-10-04  200.222748  81.629997  27.370001  10.585714  201.176544
# 2006-10-05  204.102509  82.599998  27.780001  10.647142  206.010101
# 2006-10-06  203.551102  82.500000  27.650000  10.631429  203.784576
#
# ...

# %%
all_data.tail()
# Out:
# Attributes       High                                           Low  \
# Symbols          AAPL        GOOG         IBM       MSFT       AAPL
# Date
# 2011-12-23  57.655716  315.289337  184.850006  26.040001  57.070000
# 2011-12-27  58.441429  320.162659  185.850006  26.139999  57.574287
# 2011-12-28  58.321430  320.416016  185.399994  26.150000  57.334286
# 2011-12-29  57.950001  319.422455  186.229996  26.049999  57.215714
# 2011-12-30  58.040001  321.290314  186.479996  26.120001  57.641430
#
# Attributes                                          Open              \
# Symbols           GOOG         IBM       MSFT       AAPL        GOOG
# Date
# 2011-12-23  313.242645  181.889999  25.730000  57.098572  313.958008
# 2011-12-27  313.958008  184.389999  25.930000  57.585712  313.982849
# 2011-12-28  316.988312  183.339996  25.760000  58.127144  319.298279
# 2011-12-29  315.547668  184.009995  25.860001  57.628571  318.672333
# ...

# %%
##comparing stocks graphically

# %%
all_data['Close'].plot(grid=True)
plt.show()

# %%
##histograph ploting

# %%
all_data['Volume'].hist(bins=50, sharex=False, figsize=(12,8))
plt.show()

# %%
##ploting in scaller matrix

# %%
pdr.scatter_matrix(all_daily_pct, diagonal='kde', alpha=0.1,figsize=(12,12))
plt.figure()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-46-b9c17a6286e1> in <module>()
# ----> 1 pdr.scatter_matrix(all_daily_pct, diagonal='kde', alpha=0.1,figsize=(12,12))
#       2 plt.figure()
#
# AttributeError: 'module' object has no attribute 'scatter_matrix'

# %%
##moving window

# %%
 adj_close_px = aapl['Adj Close']
moving_avg = adj_close_px.rolling(window=40).mean()
print(moving_avg[-10:])
# Out:
# Date
# 2018-12-17    191.085656
# 2018-12-18    189.779322
# 2018-12-19    188.310801
# 2018-12-20    186.689615
# 2018-12-21    185.106104
# 2018-12-24    183.308669
# 2018-12-26    181.855454
# 2018-12-27    180.477562
# 2018-12-28    179.075367
# 2018-12-31    177.572836
# Name: Adj Close, dtype: float64

# %%
aapl['week'] = adj_close_px.rolling(window=42).mean()
aapl['daily'] = adj_close_px.rolling(window=252).mean()
aapl[['Adj Close', 'week', 'daily']].plot()
plt.show()

# %%
##volatility for apple

# %%
min_periods = 75 
vol = daily_pct_change.rolling(min_periods).std() * np.sqrt(min_periods) 
vol.plot(figsize=(10, 8))
plt.show()

# %%
##volatility comparing

# %%
min_periods = 75 
vol = all_daily_pct.rolling(min_periods).std() * np.sqrt(min_periods) 
vol.plot(figsize=(10, 8))
plt.show()

# %%
short_window = 40
long_window = 100
signals = pd.DataFrame(index=aapl.index)
signals['signal'] = 0.0
signals['short_mavg'] = aapl['Close'].rolling(window=short_window, min_periods=1, center=False).mean()
signals['long_mavg'] = aapl['Close'].rolling(window=long_window, min_periods=1, center=False).mean()
signals['signal'][short_window:] = np.where(signals['short_mavg'][short_window:] 
                                            > signals['long_mavg'][short_window:], 1.0, 0.0)   
signals['positions'] = signals['signal'].diff()
print(signals)
# Out:
#             signal  short_mavg   long_mavg  positions
# Date
# 2011-09-30     0.0   54.474285   54.474285        NaN
# 2011-10-03     0.0   53.994286   53.994286        0.0
# 2011-10-04     0.0   53.734286   53.734286        0.0
# 2011-10-05     0.0   53.809643   53.809643        0.0
# 2011-10-06     0.0   53.829714   53.829714        0.0
# 2011-10-07     0.0   53.662857   53.662857        0.0
# 2011-10-10     0.0   53.931632   53.931632        0.0
# 2011-10-11     0.0   54.338214   54.338214        0.0
# 2011-10-12     0.0   54.684603   54.684603        0.0
# 2011-10-13     0.0   55.050857   55.050857        0.0
# 2011-10-14     0.0   55.526753   55.526753        0.0
# 2011-10-17     0.0   55.899405   55.899405        0.0
# 2011-10-18     0.0   56.239450   56.239450        0.0
# 2011-10-19     0.0   56.289898   56.289898        0.0
# 2011-10-20     0.0   56.302095   56.302095        0.0
# 2011-10-21     0.0   56.290982   56.290982        0.0
# ...

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111,  ylabel='Price in $')
aapl['Close'].plot(ax=ax1, color='r', lw=2.)
signals[['short_mavg', 'long_mavg']].plot(ax=ax1, lw=2.)
ax1.plot(signals.loc[signals.positions == 1.0].index, 
         signals.short_mavg[signals.positions == 1.0],
         '^', markersize=10, color='m')
ax1.plot(signals.loc[signals.positions == -1.0].index, 
         signals.short_mavg[signals.positions == -1.0],
         'v', markersize=10, color='k')
plt.show()

# %%
initial_capital= float(100000.0)
positions = pd.DataFrame(index=signals.index).fillna(0.0)
positions['AAPL'] = 100*signals['signal']     
portfolio = positions.multiply(aapl['Adj Close'], axis=0)
pos_diff = positions.diff()
portfolio['holdings'] = (positions.multiply(aapl['Adj Close'], axis=0)).sum(axis=1)
portfolio['cash'] = initial_capital - (pos_diff.multiply(aapl['Adj Close'], axis=0)).sum(axis=1).cumsum()   
portfolio['total'] = portfolio['cash'] + portfolio['holdings']
portfolio['returns'] = portfolio['total'].pct_change()
print(portfolio.head())
# Out:
#             AAPL  holdings      cash     total  returns
# Date
# 2011-09-30   0.0       0.0  100000.0  100000.0      NaN
# 2011-10-03   0.0       0.0  100000.0  100000.0      0.0
# 2011-10-04   0.0       0.0  100000.0  100000.0      0.0
# 2011-10-05   0.0       0.0  100000.0  100000.0      0.0
# 2011-10-06   0.0       0.0  100000.0  100000.0      0.0

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111, ylabel='Portfolio value in $')
portfolio['total'].plot(ax=ax1, lw=2.)
ax1.plot(portfolio.loc[signals.positions == 1.0].index, 
         portfolio.total[signals.positions == 1.0],
         '^', markersize=10, color='m')
ax1.plot(portfolio.loc[signals.positions == -1.0].index, 
         portfolio.total[signals.positions == -1.0],
         'v', markersize=10, color='k')
plt.show()

# %%
returns = portfolio['returns']
sharpe_ratio = np.sqrt(252) * (returns.mean() / returns.std())
print(sharpe_ratio)
# Out:
# 0.6683770771656175

# %%
window = 252 
rolling_max = aapl['Adj Close'].rolling(window, min_periods=1).max()
daily_drawdown = aapl['Adj Close']/rolling_max - 1.0
max_daily_drawdown = daily_drawdown.rolling(window, min_periods=1).min()
daily_drawdown.plot()
max_daily_drawdown.plot()
plt.show()

# %%
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-59-72655299f5ed> in <module>()
# ----> 1 model, model_data = aapl.create_prophet_model(days=90)
#
# E:\newloki\anaconda\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'create_prophet_model'
